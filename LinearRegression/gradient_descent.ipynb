# %%
import numpy as np
import pandas as pd
import math

# First Load the csv file

df = pd.read_csv("data/test_score.csv")

# %%
x = df['math']
y = df['cs']
# Out:
# 0    92
# 1    56
# 2    88
# 3    70
# 4    80
# 5    49
# 6    65
# 7    35
# 8    66
# 9    67
# Name: math, dtype: int64
